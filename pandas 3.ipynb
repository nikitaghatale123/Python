# %%
import pandas as pd

# %%
df = pd.read_csv('Bengaluru_House_Data.csv')

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath            float64
# balcony         float64
# price           float64
# dtype: object

# %%
df.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
df1 = pd.read_csv('test.csv')

# %%
df1
# Out:
#    name    age        sal    city
# 0   xyz   26.0     7555.0   sdfsd
# 1   pqr   97.0   161616.0  mumbai
# 2   abc   26.0  1641964.0    pune
# 3  sfsf    NaN     1166.0     NaN
# 4   NaN  345.0     4646.0    pune
# 5   NaN    NaN        NaN   sfsdf
# 6   NaN    NaN        NaN     NaN

# %%
#drop

# %%
col --> cols

# %%
df1.dropna(thresh=2)
# Out:
#    name    age        sal    city
# 0   xyz   26.0     7555.0   sdfsd
# 1   pqr   97.0   161616.0  mumbai
# 2   abc   26.0  1641964.0    pune
# 3  sfsf    NaN     1166.0     NaN
# 4   NaN  345.0     4646.0    pune

# %%
how -- all,any

NA,NA--all 
any

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 5      Super built-up  Area  Ready To Move                Whitefield
# 11               Plot  Area  Ready To Move                Whitefield
# ...                     ...            ...                       ...
# 13313  Super built-up  Area  Ready To Move               Uttarahalli
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df[((df['bath']>2) & (df['price']>250))] #and

df[((df['bath']>2) | (df['price']>250))]  #or
df[~((df['bath']>2) | (df['price']>250))]  #excluid
# Out:
#   Input In [3]
#     df[~((df['bath']>2) | (df['price']>250))]df[~((df['bath']>2) | (df['price']>250))]
#                                              ^
# SyntaxError: invalid syntax

# %%
df1.dropna(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 df1.dropna(inplace=True)
#
# AttributeError: 'NoneType' object has no attribute 'dropna'

# %%
df1 =  pd.read_csv('test.csv')

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
#       name    age        sal    city
# 0      xyz   26.0     7555.0   sdfsd
# 1      pqr   97.0   161616.0  mumbai
# 2      abc   26.0  1641964.0    pune
# 7   fsdafs  534.0     6464.0    pune
# 8   sdfsdf   23.0   464466.0  mumbai
# 9  rewrter   45.0    45456.0    pune

# %%
#loc and iloc


loc --> col name   --- stop included 


iloc -- integer location

# %%
df1
# Out:
#       name    age        sal    city
# 0      xyz   26.0     7555.0   sdfsd
# 1      pqr   97.0   161616.0  mumbai
# 2      abc   26.0  1641964.0    pune
# 7   fsdafs  534.0     6464.0    pune
# 8   sdfsdf   23.0   464466.0  mumbai
# 9  rewrter   45.0    45456.0    pune

# %%
df1.loc[1:2,'age':'city']
# Out:
#     age        sal    city
# 1  97.0   161616.0  mumbai
# 2  26.0  1641964.0    pune

# %%
df1.loc[7:8,['name','city']]
# Out:
#      name    city
# 7  fsdafs    pune
# 8  sdfsdf  mumbai

# %%
df1
# Out:
#       name    age        sal    city
# 0      xyz   26.0     7555.0   sdfsd
# 1      pqr   97.0   161616.0  mumbai
# 2      abc   26.0  1641964.0    pune
# 7   fsdafs  534.0     6464.0    pune
# 8   sdfsdf   23.0   464466.0  mumbai
# 9  rewrter   45.0    45456.0    pune

# %%
df1.iloc[3:4:,0:5]
# Out:
#      name    age     sal  city
# 7  fsdafs  534.0  6464.0  pune

# %%
df1.iloc[3:5,[1,3]]
# Out:
#      age  city
# 3    NaN   NaN
# 4  345.0  pune

# %%
df1.dropna(inplace=True)

# %%
df1.set_index('city',inplace=True)

# %%
df1
# Out:
#            name    age        sal
# city
# sdfsd       xyz   26.0     7555.0
# mumbai      pqr   97.0   161616.0
# pune        abc   26.0  1641964.0
# pune     fsdafs  534.0     6464.0
# mumbai   sdfsdf   23.0   464466.0
# pune    rewrter   45.0    45456.0

# %%
df1.loc['mumbai',['name','age']]
# Out:
#           name   age
# city
# mumbai     pqr  97.0
# mumbai  sdfsdf  23.0

# %%
df1.loc['pune']
# Out:
#          name    age        sal
# city
# pune      abc   26.0  1641964.0
# pune   fsdafs  534.0     6464.0
# pune  rewrter   45.0    45456.0

# %%
df1.reset_index(inplace=True)

# %%
df1
# Out:
#      city     name    age        sal
# 0   sdfsd      xyz   26.0     7555.0
# 1  mumbai      pqr   97.0   161616.0
# 2    pune      abc   26.0  1641964.0
# 3    pune   fsdafs  534.0     6464.0
# 4  mumbai   sdfsdf   23.0   464466.0
# 5    pune  rewrter   45.0    45456.0

# %%
index --> records fetch--> filter --

# %%
jobhun 1112
